# %% [markdown]
# # Military Expenditure Comapred with Country Wealth and Per Capita

# %% [markdown]
# ## Introduction

# %% [markdown]
# This analysis expands on Our World in Data's page "Military expenditure". This analysis puts military expensiture in perspective comparing it with each government's overall budget, GDP per country, and country size (in capita).
#
# Citations:
# [1] “Data Page: Military expenditure”, part of the following publication: Bastian Herre and Pablo Arriagada (2013) - “Military Personnel and Spending”. Data adapted from Stockholm International Peace Research Institute. Retrieved from https://ourworldindata.org/grapher/military-spending-sipri [online resource].
#
# [2]

# %% [markdown]
# ## Data Loading and Exploration

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
military_raw = pd.read_csv('https://raw.githubusercontent.com/nataschaminnitt/distributionofthings.analysis/main/military_expenditure/data/military-spending-sipri.csv')
gdp_raw = pd.read_excel("/Users/nataschajademinnitt/Documents/5. Learning/Distribution of Things/distributionofthings.analysis/military_expenditure/data/API_NY.GDP.MKTP.CD_DS2_en_excel_v2_31691.xls")

# %%
# remove unwanted years
military = military_raw[(military_raw['Year'] <= 2023) & (military_raw['Year'] >= 2013)].reset_index()
military.rename(columns={'Entity': 'country', 'Code': 'code', 'Year': 'year', 'Military expenditure (constant US$)': 'military_exp'}, inplace=True)
military.drop(columns='index', inplace=True)
military.head()
# Out:
#        country code  year  military_exp
# 0  Afghanistan  AFG  2013   183421710.0
# 1  Afghanistan  AFG  2014   223721970.0
# 2  Afghanistan  AFG  2015   178913870.0
# 3  Afghanistan  AFG  2016   177240050.0
# 4  Afghanistan  AFG  2017   174272690.0

# %%
gdp_raw.head()
# Out:
#                   Country Name Country Code     Indicator Name  \
# 0                        Aruba          ABW  GDP (current US$)
# 1  Africa Eastern and Southern          AFE  GDP (current US$)
# 2                  Afghanistan          AFG  GDP (current US$)
# 3   Africa Western and Central          AFW  GDP (current US$)
# 4                       Angola          AGO  GDP (current US$)
#
#    Indicator Code          1960          1961          1962          1963  \
# 0  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# 1  NY.GDP.MKTP.CD  2.121696e+10  2.230747e+10  2.370247e+10  2.577938e+10
# 2  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# 3  NY.GDP.MKTP.CD  1.188413e+10  1.268566e+10  1.360683e+10  1.443998e+10
# 4  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
#
#            1964          1965  ...          2014          2015          2016  \
# ...

# %%
gdp = gdp_raw[['Country Name', 'Country Code', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023']].copy()
gdp.rename(columns={'Country Name': 'country', 'Country Code' : 'code'}, inplace=True)

# %%
# Use pd.melt to reshape the DataFrame
gdp_melted = pd.melt(gdp, id_vars=['country', 'code'], var_name='year', value_name='gdp')

# If the years are treated as strings, you can convert them to integers:
gdp_melted['year'] = gdp_melted['year'].astype(int)

# Display the reshaped DataFrame
gdp_melted.sort_values(['country', 'year'])
# Out:
#           country code  year           gdp
# 2     Afghanistan  AFG  2013  2.014642e+10
# 268   Afghanistan  AFG  2014  2.049713e+10
# 534   Afghanistan  AFG  2015  1.913422e+10
# 800   Afghanistan  AFG  2016  1.811657e+10
# 1066  Afghanistan  AFG  2017  1.875346e+10
# ...           ...  ...   ...           ...
# 1861     Zimbabwe  ZWE  2019  2.183223e+10
# 2127     Zimbabwe  ZWE  2020  2.150970e+10
# 2393     Zimbabwe  ZWE  2021  2.837124e+10
# 2659     Zimbabwe  ZWE  2022  2.736663e+10
# 2925     Zimbabwe  ZWE  2023  2.653827e+10
#
# [2926 rows x 4 columns]

# %%
# Merge the datasets on both 'country' and 'year'
merged_data = pd.merge(military, gdp_melted, on=['country', 'code', 'year'], how='inner')

# Display the first few rows of the merged dataset
merged_data.head()
# Out:
#        country code  year  military_exp           gdp
# 0  Afghanistan  AFG  2013   183421710.0  2.014642e+10
# 1  Afghanistan  AFG  2014   223721970.0  2.049713e+10
# 2  Afghanistan  AFG  2015   178913870.0  1.913422e+10
# 3  Afghanistan  AFG  2016   177240050.0  1.811657e+10
# 4  Afghanistan  AFG  2017   174272690.0  1.875346e+10

# %%
merged_data['percent'] = merged_data['military_exp'] / merged_data['gdp'] * 100
merged_data.head()
# Out:
#        country code  year  military_exp           gdp   percent
# 0  Afghanistan  AFG  2013   183421710.0  2.014642e+10  0.910443
# 1  Afghanistan  AFG  2014   223721970.0  2.049713e+10  1.091480
# 2  Afghanistan  AFG  2015   178913870.0  1.913422e+10  0.935047
# 3  Afghanistan  AFG  2016   177240050.0  1.811657e+10  0.978331
# 4  Afghanistan  AFG  2017   174272690.0  1.875346e+10  0.929283

# %%
# Group by 'year' and calculate the mean, and store it as a DataFrame
world_year_ave = merged_data.groupby('year')[['military_exp', 'gdp', 'percent']].mean().reset_index()

# Display the first 12 rows
world_year_ave.head(12)
# Out:
#     year  military_exp           gdp   percent
# 0   2013  1.268501e+10  5.104591e+11  1.918813
# 1   2014  1.237443e+10  5.182848e+11  1.983738
# 2   2015  1.247304e+10  4.979842e+11  2.172904
# 3   2016  1.234092e+10  5.067913e+11  2.046309
# 4   2017  1.259172e+10  5.392402e+11  1.938953
# 5   2018  1.288657e+10  5.718401e+11  1.826620
# 6   2019  1.350115e+10  5.848370e+11  1.896750
# 7   2020  1.401798e+10  5.701077e+11  2.030172
# 8   2021  1.405769e+10  6.456285e+11  1.849824
# 9   2022  1.467143e+10  6.770039e+11  1.879336
# 10  2023  1.552033e+10  7.160198e+11  1.984652

# %%
average = merged_data.groupby('country')['percent'].mean()
# Out:
# country
# Afghanistan    1.146381
# Albania        1.390519
# Algeria        5.192076
# Angola         3.723952
# Argentina      0.824336
# Name: percent, dtype: float64

# %%
average.describe()
# Out:
# count    142.000000
# mean       2.147188
# std        2.372163
# min        0.000000
# 25%        1.048687
# 50%        1.484529
# 75%        2.352172
# max       21.639376
# Name: percent, dtype: float64

# %%
# Define the list of countries you want to filter
countries = ['United States', 'China', 'Saudi Arabia', 'Israel', 'Germany', 'Japan', 'India', 'Russia', 'Brazil']

# Filter the DataFrame for these countries
select_countries = merged_data[merged_data['country'].isin(countries)]

# Display the first few rows of the filtered DataFrame
select_countries.head()
# Out:
#     country code  year  military_exp           gdp   percent
# 196  Brazil  BRA  2013  2.351249e+10  2.472820e+12  0.950837
# 197  Brazil  BRA  2014  2.398267e+10  2.456044e+12  0.976476
# 198  Brazil  BRA  2015  2.342689e+10  1.802212e+12  1.299896
# 199  Brazil  BRA  2016  2.223762e+10  1.795693e+12  1.238386
# 200  Brazil  BRA  2017  2.368719e+10  2.063515e+12  1.147905

# %%
sns.set_style('whitegrid')

# Plot with a line for each country using the 'hue' parameter
sns.lineplot(data=select_countries, x='year', y='percent', hue='country', marker='o', linewidth=1)

# Add labels and title
plt.xlabel('Year')
plt.ylabel('Percent Military Expenditure vs GDP')
plt.title('Military Expenditure as Percentage of GDP Over Time')

# Show the plot
plt.show()
